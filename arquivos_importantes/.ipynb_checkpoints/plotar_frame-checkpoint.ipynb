# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %%
data=pd.read_csv('teste2.txt',sep=';',header=1, decimal=",")
data
# Out:
#        n   x  luma  Unnamed: 3
# 0      0 NaN   NaN         NaN
# 1      1 NaN   NaN         NaN
# 2      2 NaN   NaN         NaN
# 3      3 NaN   NaN         NaN
# 4      4 NaN   NaN         NaN
# ..   ...  ..   ...         ...
# 626  626 NaN   NaN         NaN
# 627  627 NaN   NaN         NaN
# 628  628 NaN   NaN         NaN
# 629  629 NaN   NaN         NaN
# 630  630 NaN   NaN         NaN
#
# [631 rows x 4 columns]

# %%
data=pd.read_csv('teste.txt',sep=';',header=1, decimal=",")

# %%
data=pd.read_csv('teste.txt',sep=';',header=1, decimal=",")

# %%
data['luma']
# Out:
# 0      187.2
# 1      183.0
# 2      181.7
# 3      182.9
# 4      184.5
#        ...
# 626    183.9
# 627    186.7
# 628    188.8
# 629    190.9
# 630    189.9
# Name: luma, Length: 631, dtype: float64

# %%
b, a = signal.butter(1, 0.025)
x=data['luma']
y = signal.filtfilt(b, a,x , padlen=150)
plt.plot(x)
plt.plot(y)
figs=plt.subplot(2,1,figsize=(4,3))
figs[0].plot(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[42], line 6
#       4 plt.plot(x)
#       5 plt.plot(y)
# ----> 6 figs=plt.subplot(2,1,figsize=(4,3))
#       7 figs[0].plot(x)
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/pyplot.py:1323, in subplot(*args, **kwargs)
#    1320 fig = gcf()
#    1322 # First, search for an existing subplot with a matching spec.
# -> 1323 key = SubplotSpec._from_subplot_args(fig, args)
#    1325 for ax in fig.axes:
#    1326     # if we found an Axes at the position sort out if we can re-use it
#    1327     if ax.get_subplotspec() == key:
#    1328         # if the user passed no kwargs, re-use
#
# File /usr/local/lib/python3.11/site-packages/matplotlib/gridspec.py:585, in SubplotSpec._from_subplot_args(figure, args)
#     583     rows, cols, num = args
#     584 else:
# --> 585     raise _api.nargs_error("subplot", takes="1 or 3", given=len(args))
#     587 gs = GridSpec._check_gridspec_exists(figure, rows, cols)
#     588 if gs is None:
#
# TypeError: subplot() takes 1 or 3 positional arguments but 2 were given

# %%
plt.plot(np.diff(x))
plt.plot(np.diff(y))
